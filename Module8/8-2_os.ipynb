# %%
# 匯入套件
import os

# 檔案路徑
folder_path = "../Module7"
files = os.listdir(folder_path)

print(files)

# 如果指定路徑的檔案存在，則執行刪除
file_path = "data.txt"
print(os.path.exists(file_path))
if os.path.exists(file_path):
    os.remove(file_path)
# Out:
# ['7-1_try_except.ipynb', '7-2_raise.ipynb', 'README.md']
# True

# %%
import json, os
# os.mkdir() 建立資料夾
folder = "test"
if not os.path.exists(folder):
    os.mkdir(folder)

with open(f"{folder}/123.json", "w", encoding="utf-8") as f:
    json.dump([1, 2, 3], f)
